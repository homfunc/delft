# %%
import os

from delft.sequenceLabelling.wrapper import Sequence
# Out:
# 2025-09-04 08:58:05.699295: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-04 08:58:05.741005: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-04 08:58:05.954717: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-04 08:58:06.178934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
seq = Sequence("ner-fr-lemonde-BidLSTM_ChainCRF")

# %%
seq.load(dir_path='data/models/sequenceLabelling/', skip_embeddings=True)
# Out:
# BidLSTM_ChainCRF
# 2025-09-04 09:06:03.868932: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# load weights from data/models/sequenceLabelling/ner-fr-lemonde-BidLSTM_ChainCRF/model_weights.hdf5
# loading model weights data/models/sequenceLabelling/ner-fr-lemonde-BidLSTM_ChainCRF/model_weights.hdf5
# Standard load_weights failed, attempting legacy HDF5 by-name loading: Layer count mismatch when loading weights from file. Model expected 2 layers, found 6 saved layers.
# Assigned 18 variables from legacy file; missing 0
# Converted legacy weights to data/models/sequenceLabelling/ner-fr-lemonde-BidLSTM_ChainCRF/model.keras
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# ...
